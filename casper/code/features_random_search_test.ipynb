# %%
"""
This script finds the best hyperparameter combination using random Search

This script may takes several days to complete
If FAST_MODE = True, it will directly read the fitness of a chromosome from 'results/fitness_table' generated by Grid Search

"""

import numpy as np
import pandas as pd
from utilities import set_seed
from hypers_grid_search import HYPERPARAMETERS_CANDIDATES
from hypers_grid_search import SEARCH_SPACE_SIZE


DNA_SIZE = 15

# set seed
SEED = None
if SEED is not None:
    set_seed(SEED)


# The scores for all 4096 possible chromosomes
FITNESS_TABLE = pd.read_csv('results/feature_selection_fitness.csv', index_col=0, dtype={0: str})

def random_search_test():
    """
    Randomly sample hyperparameters and evaluate them
    """

    top_10s = FITNESS_TABLE.sort_values(by='MSE', ascending=True).head(10)

    num_gen_to_get_the_best = 0
    num_gen_to_get_top_10 = 0
    top_10_obtained = False

    n_sample = 1
    while(True):
        chromosome = ''.join(map(str, np.random.randint(2, size=DNA_SIZE)))

        if not top_10_obtained and chromosome in top_10s.index:
            top_10_obtained = True
            num_gen_to_get_top_10 = n_sample
        
        if chromosome == top_10s.index[0]:
            num_gen_to_get_the_best = n_sample
            break

        n_sample += 1

    return num_gen_to_get_the_best, num_gen_to_get_top_10

# %%
# Run GA search 2000 times
NUM_TEST = 2000
result = []
for i in range(1, NUM_TEST + 1):
    num_gen_to_get_the_best, num_gen_to_get_top_10 = random_search_test()
    result.append([num_gen_to_get_the_best, num_gen_to_get_top_10])
    if i % 20 == 0:
        print(f'{i}/{NUM_TEST}   Number of Gen to get the best chromosome: {num_gen_to_get_the_best}   Number of Gen to get one of the top 10s: {num_gen_to_get_top_10}')
result = np.array(result)

num_gen_to_get_the_best = result[:, 0]
num_gen_to_get_top_10 = result[:, 1]
# Out:
# 20/2000   Number of Gen to get the best chromosome: 1530   Number of Gen to get one of the top 10s: 1530
# 40/2000   Number of Gen to get the best chromosome: 179990   Number of Gen to get one of the top 10s: 1196
# 60/2000   Number of Gen to get the best chromosome: 30271   Number of Gen to get one of the top 10s: 5934
# 80/2000   Number of Gen to get the best chromosome: 893   Number of Gen to get one of the top 10s: 893
# 100/2000   Number of Gen to get the best chromosome: 30930   Number of Gen to get one of the top 10s: 13363
# 120/2000   Number of Gen to get the best chromosome: 13314   Number of Gen to get one of the top 10s: 5507
# 140/2000   Number of Gen to get the best chromosome: 9637   Number of Gen to get one of the top 10s: 985
# 160/2000   Number of Gen to get the best chromosome: 38350   Number of Gen to get one of the top 10s: 326
# 180/2000   Number of Gen to get the best chromosome: 1845   Number of Gen to get one of the top 10s: 1283
# 200/2000   Number of Gen to get the best chromosome: 12927   Number of Gen to get one of the top 10s: 12180
# 220/2000   Number of Gen to get the best chromosome: 3960   Number of Gen to get one of the top 10s: 3960
# 240/2000   Number of Gen to get the best chromosome: 1270   Number of Gen to get one of the top 10s: 1270
# 260/2000   Number of Gen to get the best chromosome: 14650   Number of Gen to get one of the top 10s: 1073
# 280/2000   Number of Gen to get the best chromosome: 5815   Number of Gen to get one of the top 10s: 159
# 300/2000   Number of Gen to get the best chromosome: 145702   Number of Gen to get one of the top 10s: 4171
# 320/2000   Number of Gen to get the best chromosome: 13727   Number of Gen to get one of the top 10s: 8905
# 340/2000   Number of Gen to get the best chromosome: 21686   Number of Gen to get one of the top 10s: 7994
# 360/2000   Number of Gen to get the best chromosome: 9689   Number of Gen to get one of the top 10s: 585
# 380/2000   Number of Gen to get the best chromosome: 20245   Number of Gen to get one of the top 10s: 10574
# 400/2000   Number of Gen to get the best chromosome: 99582   Number of Gen to get one of the top 10s: 1952
# 420/2000   Number of Gen to get the best chromosome: 135286   Number of Gen to get one of the top 10s: 1081
# 440/2000   Number of Gen to get the best chromosome: 16041   Number of Gen to get one of the top 10s: 1093
# 460/2000   Number of Gen to get the best chromosome: 44354   Number of Gen to get one of the top 10s: 3387
# 480/2000   Number of Gen to get the best chromosome: 93380   Number of Gen to get one of the top 10s: 51
# 500/2000   Number of Gen to get the best chromosome: 8094   Number of Gen to get one of the top 10s: 961
# 520/2000   Number of Gen to get the best chromosome: 28384   Number of Gen to get one of the top 10s: 2859
# 540/2000   Number of Gen to get the best chromosome: 15125   Number of Gen to get one of the top 10s: 4019
# 560/2000   Number of Gen to get the best chromosome: 47089   Number of Gen to get one of the top 10s: 3542
# 580/2000   Number of Gen to get the best chromosome: 34633   Number of Gen to get one of the top 10s: 58
# 600/2000   Number of Gen to get the best chromosome: 89612   Number of Gen to get one of the top 10s: 8371
# 620/2000   Number of Gen to get the best chromosome: 21656   Number of Gen to get one of the top 10s: 293
# 640/2000   Number of Gen to get the best chromosome: 10072   Number of Gen to get one of the top 10s: 2296
# 660/2000   Number of Gen to get the best chromosome: 1147   Number of Gen to get one of the top 10s: 513
# 680/2000   Number of Gen to get the best chromosome: 92819   Number of Gen to get one of the top 10s: 114
# 700/2000   Number of Gen to get the best chromosome: 13280   Number of Gen to get one of the top 10s: 8459
# 720/2000   Number of Gen to get the best chromosome: 64319   Number of Gen to get one of the top 10s: 9097
# 740/2000   Number of Gen to get the best chromosome: 5916   Number of Gen to get one of the top 10s: 5916
# 760/2000   Number of Gen to get the best chromosome: 37342   Number of Gen to get one of the top 10s: 3771
# 780/2000   Number of Gen to get the best chromosome: 4620   Number of Gen to get one of the top 10s: 461
# 800/2000   Number of Gen to get the best chromosome: 862   Number of Gen to get one of the top 10s: 862
# 820/2000   Number of Gen to get the best chromosome: 86521   Number of Gen to get one of the top 10s: 4633
# 840/2000   Number of Gen to get the best chromosome: 73830   Number of Gen to get one of the top 10s: 3519
# 860/2000   Number of Gen to get the best chromosome: 7773   Number of Gen to get one of the top 10s: 495
# 880/2000   Number of Gen to get the best chromosome: 27414   Number of Gen to get one of the top 10s: 1861
# 900/2000   Number of Gen to get the best chromosome: 27791   Number of Gen to get one of the top 10s: 675
# 920/2000   Number of Gen to get the best chromosome: 7974   Number of Gen to get one of the top 10s: 1587
# 940/2000   Number of Gen to get the best chromosome: 26412   Number of Gen to get one of the top 10s: 8131
# 960/2000   Number of Gen to get the best chromosome: 39241   Number of Gen to get one of the top 10s: 1356
# 980/2000   Number of Gen to get the best chromosome: 31848   Number of Gen to get one of the top 10s: 4481
# 1000/2000   Number of Gen to get the best chromosome: 31765   Number of Gen to get one of the top 10s: 4013
# 1020/2000   Number of Gen to get the best chromosome: 25154   Number of Gen to get one of the top 10s: 5724
# 1040/2000   Number of Gen to get the best chromosome: 9927   Number of Gen to get one of the top 10s: 1566
# 1060/2000   Number of Gen to get the best chromosome: 108482   Number of Gen to get one of the top 10s: 1289
# 1080/2000   Number of Gen to get the best chromosome: 14008   Number of Gen to get one of the top 10s: 5467
# 1100/2000   Number of Gen to get the best chromosome: 13375   Number of Gen to get one of the top 10s: 1883
# 1120/2000   Number of Gen to get the best chromosome: 1893   Number of Gen to get one of the top 10s: 1893
# 1140/2000   Number of Gen to get the best chromosome: 10650   Number of Gen to get one of the top 10s: 4976
# 1160/2000   Number of Gen to get the best chromosome: 81   Number of Gen to get one of the top 10s: 81
# 1180/2000   Number of Gen to get the best chromosome: 33694   Number of Gen to get one of the top 10s: 829
# 1200/2000   Number of Gen to get the best chromosome: 4398   Number of Gen to get one of the top 10s: 2844
# 1220/2000   Number of Gen to get the best chromosome: 4245   Number of Gen to get one of the top 10s: 4245
# 1240/2000   Number of Gen to get the best chromosome: 49603   Number of Gen to get one of the top 10s: 2419
# 1260/2000   Number of Gen to get the best chromosome: 47479   Number of Gen to get one of the top 10s: 8554
# 1280/2000   Number of Gen to get the best chromosome: 34766   Number of Gen to get one of the top 10s: 3930
# 1300/2000   Number of Gen to get the best chromosome: 34729   Number of Gen to get one of the top 10s: 1196
# 1320/2000   Number of Gen to get the best chromosome: 129193   Number of Gen to get one of the top 10s: 2239
# 1340/2000   Number of Gen to get the best chromosome: 74380   Number of Gen to get one of the top 10s: 8259
# 1360/2000   Number of Gen to get the best chromosome: 11418   Number of Gen to get one of the top 10s: 2249
# 1380/2000   Number of Gen to get the best chromosome: 56019   Number of Gen to get one of the top 10s: 478
# 1400/2000   Number of Gen to get the best chromosome: 11302   Number of Gen to get one of the top 10s: 4225
# 1420/2000   Number of Gen to get the best chromosome: 3784   Number of Gen to get one of the top 10s: 133
# 1440/2000   Number of Gen to get the best chromosome: 64636   Number of Gen to get one of the top 10s: 6394
# 1460/2000   Number of Gen to get the best chromosome: 50760   Number of Gen to get one of the top 10s: 1020
# 1480/2000   Number of Gen to get the best chromosome: 11711   Number of Gen to get one of the top 10s: 11622
# 1500/2000   Number of Gen to get the best chromosome: 13040   Number of Gen to get one of the top 10s: 4033
# 1520/2000   Number of Gen to get the best chromosome: 55000   Number of Gen to get one of the top 10s: 3320
# 1540/2000   Number of Gen to get the best chromosome: 115749   Number of Gen to get one of the top 10s: 16675
# 1560/2000   Number of Gen to get the best chromosome: 1264   Number of Gen to get one of the top 10s: 1264
# 1580/2000   Number of Gen to get the best chromosome: 34584   Number of Gen to get one of the top 10s: 169
# 1600/2000   Number of Gen to get the best chromosome: 6120   Number of Gen to get one of the top 10s: 2969
# 1620/2000   Number of Gen to get the best chromosome: 45560   Number of Gen to get one of the top 10s: 5731
# 1640/2000   Number of Gen to get the best chromosome: 11519   Number of Gen to get one of the top 10s: 878
# 1660/2000   Number of Gen to get the best chromosome: 6630   Number of Gen to get one of the top 10s: 953
# 1680/2000   Number of Gen to get the best chromosome: 26915   Number of Gen to get one of the top 10s: 4089
# 1700/2000   Number of Gen to get the best chromosome: 20466   Number of Gen to get one of the top 10s: 14123
# 1720/2000   Number of Gen to get the best chromosome: 36574   Number of Gen to get one of the top 10s: 944
# 1740/2000   Number of Gen to get the best chromosome: 59934   Number of Gen to get one of the top 10s: 453
# 1760/2000   Number of Gen to get the best chromosome: 11377   Number of Gen to get one of the top 10s: 9310
# 1780/2000   Number of Gen to get the best chromosome: 61149   Number of Gen to get one of the top 10s: 15115
# 1800/2000   Number of Gen to get the best chromosome: 43557   Number of Gen to get one of the top 10s: 3349
# 1820/2000   Number of Gen to get the best chromosome: 51219   Number of Gen to get one of the top 10s: 3263
# 1840/2000   Number of Gen to get the best chromosome: 12578   Number of Gen to get one of the top 10s: 3752
# 1860/2000   Number of Gen to get the best chromosome: 26555   Number of Gen to get one of the top 10s: 5634
# 1880/2000   Number of Gen to get the best chromosome: 75816   Number of Gen to get one of the top 10s: 8
# 1900/2000   Number of Gen to get the best chromosome: 16782   Number of Gen to get one of the top 10s: 2726
# 1920/2000   Number of Gen to get the best chromosome: 998   Number of Gen to get one of the top 10s: 998
# 1940/2000   Number of Gen to get the best chromosome: 32303   Number of Gen to get one of the top 10s: 8632
# 1960/2000   Number of Gen to get the best chromosome: 9946   Number of Gen to get one of the top 10s: 2335
# 1980/2000   Number of Gen to get the best chromosome: 8950   Number of Gen to get one of the top 10s: 6
# 2000/2000   Number of Gen to get the best chromosome: 14776   Number of Gen to get one of the top 10s: 2023

# %%
print()
print("Number of Gen to get the best chromosome:")
print(f'Mean: {np.mean(num_gen_to_get_the_best)}')
print(f'Median: {np.median(num_gen_to_get_the_best)}')
print(f'Standard Deviation: {np.std(num_gen_to_get_the_best)}')
print()
print("Number of Gen to get one of the top 10s:")
print(f'Mean: {np.mean(num_gen_to_get_top_10)}')
print(f'Median: {np.median(num_gen_to_get_top_10)}')
print(f'Standard Deviation: {np.std(num_gen_to_get_top_10)}')
# Out:
# Number of Gen to get the best chromosome:
# Mean: 32065.2475
# Median: 21581.5
# Standard Deviation: 31896.728752165855
#
# Number of Gen to get one of the top 10s:
# Mean: 3233.266
# Median: 2297.0
# Standard Deviation: 3193.9749445235166
