# %% [markdown]
# ### This script is used to find the best hyperparameter combination using Grid Search
# ### by training the model (with oversampling) over all feature
# The test result of the model with the the best hyperparameter combination will then be used to compare with the model that is trained on selected features chosen by GA

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from utilities import import_data
from utilities import set_seed
from casper_test import final_test
from casper_test import rkf_validator
from sklearn.model_selection import train_test_split

# %%
# select training device
device = "cpu"
    
# make results determinstic
seed = 4660
if seed != None:
    set_seed(seed)
    
# Define hyperparameter candidates
# hyperparameters = {'max_hidden_neurons': 5,
#                    'P': 1,
#                    'D': 0.005,
#                    'lrs': [0.2, 0.005, 0.001]}

hyperparameters_candidates = {'max_hidden_neurons': [1, 5, 10, 15],
                   'P': [0.1, 1, 5, 10],
                   'D': [0, 0.005, 0.05],
                   'lrs': [[0.5, 0.01, 0.005], [0.2, 0.005, 0.001], [0.05, 0.01, 0.0005]]}

# hyperparameters_candidates = {'max_hidden_neurons': [1, 5],
#                    'P': [1, 2],
#                    'D': [0.005],
#                    'lrs': [[0.05, 0.01, 0.0005]]}

# import data
data, _, _ = import_data()
train_data, test_data, _, _ = train_test_split(data, data.iloc[:,0], test_size=0.2, random_state=seed)

n_splits = 10
n_repeats = 4

# %%
scores = []
hyperparameter_combinations = []

# %%
def grid_search(data, hyperparameters_candidates, n_splits, n_repeats, device='cpu'):
    print(f"Sample Size: {data.shape[0]}")
    start_time = time.time()
    num_of_combinations = (len(hyperparameters_candidates['max_hidden_neurons']) * 
                           len(hyperparameters_candidates['P']) * 
                           len(hyperparameters_candidates['D']) * 
                           len(hyperparameters_candidates['lrs'])) 
    count = 1
    for max_hidden_neurons in hyperparameters_candidates['max_hidden_neurons']:
        for P in hyperparameters_candidates['P']:
            for D in hyperparameters_candidates['D']:
                for lrs in hyperparameters_candidates['lrs']:
                    hyperparameters = {'max_hidden_neurons': max_hidden_neurons,
                                       'P': P,
                                       'D': D,
                                       'lrs': lrs}
                    score = rkf_validator(data, hyperparameters, n_splits, n_repeats, device=device, fast_mode=True, verbose=False, oversampling=True)
                    print(f"Searched Hyperparameter Combination: {count}/{num_of_combinations}   MSE: {score}", end = '\r')
                    scores.append(score)
                    hyperparameter_combinations.append(hyperparameters)
                    count += 1
    print(f"Grid Search Finished, Spent: {time.time() - start_time}s")

# %%
# Grid Search
grid_search(train_data, hyperparameters_candidates, n_splits, n_repeats, device='cpu')
# Out:
# Sample Size: 208
# Grid Search Finished, Spent: 4574.905390262604sMSE: 6.1243031561374675

# %%
# Save all hyperparameter combinations
with open('results/grid_search_no_GA.pkl', 'wb') as fp:
    pickle.dump(hyperparameter_combinations, fp)
# with open('results/grid_search_no_GA.pkl', 'rb') as fp:
#     hyperparameter_combinations = pickle.load(fp)
    
# Save all scores corresponding to different hyperparameter combinations
with open('results/grid_search_no_GA.npy', 'wb') as f:
    np.save(f, scores)
# with open('results/grid_search_no_GA.npy', 'rb') as f:
#     scores = np.load(f)

best_hyperparameters = hyperparameter_combinations[np.argmin(scores)]
print(f"best score: {np.min(scores)}")
print(f"best hyperparameters: {best_hyperparameters}")
# Out:
# best score: 3.2223126113414766
# best hyperparameters: {'max_hidden_neurons': 1, 'P': 5, 'D': 0.05, 'lrs': [0.5, 0.01, 0.005]}

# %%
final_test(data, best_hyperparameters, 10, 20, device=device)
# Out:
# Model is trained 200 times
# with each run has different test-training split and initialised weights
# Mean: 3.052055931389331624    MAE: 1.5968
# Median: 2.899346709251404
# Standard Deviation: 0.8797212521051944
#
# Mean: 1.4200051298737526
# Median: 1.412195086479187
# Standard Deviation: 0.21272096067720145
# Class 1
# Number of runs that contain MSE/MAE for this class: 38
# MSE: average over all 38 runs: 15.4900
# MSE: median over all 38 runs: 16.2813
# MSE: std over all 38 runs: 4.2029
# L1E: average of MAE over all 38 runs: 3.8949
# L1E: median over all 38 runs: 4.0312
# L1E std over all 38 runs: 0.5626
#
# Class 2
# Number of runs that contain MSE/MAE for this class: 154
# MSE: average over all 154 runs: 6.1124
# MSE: median over all 154 runs: 5.1761
# MSE: std over all 154 runs: 4.7175
# L1E: average of MAE over all 154 runs: 2.1254
# L1E: median over all 154 runs: 2.1748
# L1E std over all 154 runs: 0.9970
#
# Class 3
# Number of runs that contain MSE/MAE for this class: 191
# MSE: average over all 191 runs: 3.9079
# MSE: median over all 191 runs: 3.4877
# MSE: std over all 191 runs: 3.1434
# L1E: average of MAE over all 191 runs: 1.6658
# L1E: median over all 191 runs: 1.6314
# L1E std over all 191 runs: 0.6752
#
# Class 4
# Number of runs that contain MSE/MAE for this class: 198
# MSE: average over all 198 runs: 1.5354
# MSE: median over all 198 runs: 1.3017
# MSE: std over all 198 runs: 1.5094
# L1E: average of MAE over all 198 runs: 1.0176
# L1E: median over all 198 runs: 0.9793
# L1E std over all 198 runs: 0.4167
#
# Class 5
# Number of runs that contain MSE/MAE for this class: 200
# MSE: average over all 200 runs: 1.6609
# MSE: median over all 200 runs: 1.4601
# MSE: std over all 200 runs: 1.0812
# L1E: average of MAE over all 200 runs: 1.0116
# L1E: median over all 200 runs: 1.0141
# L1E std over all 200 runs: 0.3241
#
# Class 6
# Number of runs that contain MSE/MAE for this class: 200
# MSE: average over all 200 runs: 2.8696
# MSE: median over all 200 runs: 2.7186
# MSE: std over all 200 runs: 1.2023
# L1E: average of MAE over all 200 runs: 1.4649
# L1E: median over all 200 runs: 1.4387
# L1E std over all 200 runs: 0.3524
#
# Class 7
# Number of runs that contain MSE/MAE for this class: 182
# MSE: average over all 182 runs: 6.3914
# MSE: median over all 182 runs: 5.8979
# MSE: std over all 182 runs: 3.8039
# L1E: average of MAE over all 182 runs: 2.3024
# L1E: median over all 182 runs: 2.2736
# L1E std over all 182 runs: 0.7835
